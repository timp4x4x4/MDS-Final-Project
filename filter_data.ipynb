# %%
import pandas as pd

# %%
df = pd.read_csv("US_Accidents_2022.csv")
df
# Out:
#                 ID   Source  Severity           Start_Time  \
# 0         A-512230  Source2         1  2022-09-08 05:49:30
# 1         A-512231  Source2         1  2022-09-08 02:02:05
# 2         A-512232  Source2         1  2022-09-08 05:14:12
# 3         A-512233  Source2         1  2022-09-08 06:22:57
# 4         A-512234  Source2         2  2022-09-08 06:36:20
# ...            ...      ...       ...                  ...
# 1762447  A-5464714  Source1         2  2022-10-08 13:29:50
# 1762448  A-5464715  Source1         2  2022-10-11 05:30:00
# 1762449  A-5464716  Source1         2  2022-08-25 09:41:00
# 1762450  A-5464717  Source1         2  2022-06-28 14:18:09
# 1762451  A-5464718  Source1         2  2022-09-18 08:48:00
#
#                               End_Time  Start_Lat   Start_Lng    End_Lat  \
# 0                  2022-09-08 06:34:53  41.946796  -88.208092        NaN
# 1                  2022-09-08 04:31:32  34.521172 -117.958076        NaN
# 2                  2022-09-08 07:38:17  37.542839  -77.441780        NaN
# 3                  2022-09-08 06:52:42  40.896629  -81.178452        NaN
# 4                  2022-09-08 07:05:58  41.409359  -81.644318        NaN
# ...                                ...        ...         ...        ...
# 1762447  2022-10-08 14:44:50.000000000  32.916783  -96.717758  32.916294
# 1762448  2022-10-11 06:47:57.000000000  33.882405 -117.364874  33.882406
# 1762449  2022-08-25 11:00:54.000000000  33.882416 -117.366134  33.882414
# 1762450  2022-06-28 19:29:33.000000000  40.692173  -73.550584  40.705595
# 1762451  2022-09-18 10:30:00.000000000  30.257131  -97.611813  30.256604
#
#             End_Lng  Distance(mi)  ... Roundabout Station   Stop  \
# 0               NaN         0.000  ...      False   False  False
# 1               NaN         0.000  ...      False   False  False
# 2               NaN         0.000  ...      False   False  False
# 3               NaN         0.000  ...      False   False  False
# 4               NaN         1.910  ...      False   False  False
# ...             ...           ...  ...        ...     ...    ...
# 1762447  -96.717758         0.034  ...      False   False  False
# 1762448 -117.365524         0.037  ...      False   False  False
# 1762449 -117.366349         0.012  ...      False   False  False
# 1762450  -73.450696         5.314  ...      False   False  False
# 1762451  -97.612163         0.042  ...      False   False  False
#
#         Traffic_Calming Traffic_Signal Turning_Loop Sunrise_Sunset  \
# 0                 False           True        False          Night
# 1                 False          False        False          Night
# 2                 False           True        False          Night
# 3                 False          False        False          Night
# 4                 False          False        False          Night
# ...                 ...            ...          ...            ...
# 1762447           False           True        False            Day
# 1762448           False          False        False          Night
# 1762449           False           True        False            Day
# 1762450           False          False        False            Day
# 1762451           False           True        False            Day
#
#         Civil_Twilight Nautical_Twilight Astronomical_Twilight
# 0                Night               Day                   Day
# 1                Night             Night                 Night
# 2                Night             Night                 Night
# 3                Night               Day                   Day
# 4                  Day               Day                   Day
# ...                ...               ...                   ...
# 1762447            Day               Day                   Day
# 1762448          Night             Night                   Day
# 1762449            Day               Day                   Day
# 1762450            Day               Day                   Day
# 1762451            Day               Day                   Day
#
# [1762452 rows x 46 columns]

# %%
df.columns
# Out:
# Index(['ID', 'Source', 'Severity', 'Start_Time', 'End_Time', 'Start_Lat',
#        'Start_Lng', 'End_Lat', 'End_Lng', 'Distance(mi)', 'Description',
#        'Street', 'City', 'County', 'State', 'Zipcode', 'Country', 'Timezone',
#        'Airport_Code', 'Weather_Timestamp', 'Temperature(F)', 'Wind_Chill(F)',
#        'Humidity(%)', 'Pressure(in)', 'Visibility(mi)', 'Wind_Direction',
#        'Wind_Speed(mph)', 'Precipitation(in)', 'Weather_Condition', 'Amenity',
#        'Bump', 'Crossing', 'Give_Way', 'Junction', 'No_Exit', 'Railway',
#        'Roundabout', 'Station', 'Stop', 'Traffic_Calming', 'Traffic_Signal',
#        'Turning_Loop', 'Sunrise_Sunset', 'Civil_Twilight', 'Nautical_Twilight',
#        'Astronomical_Twilight'],
#       dtype='object')

# %%
severity_counts = df['Severity'].value_counts()
print(severity_counts)
# Out:
# Severity
# 2    1603346
# 3      77957
# 4      43274
# 1      37875
# Name: count, dtype: int64

# %%
# 先把有 NaN 的列刪掉
df = df.drop(columns=['End_Lat', 'End_Lng'])
df_clean = df.dropna()

severity_counts = df_clean['Severity'].value_counts()
print(severity_counts)
# Out:
# Severity
# 2    1496207
# 3      72449
# 4      38056
# 1      35880
# Name: count, dtype: int64

# %%
# df_clean.to_csv('cleaned_2022.csv', index=False)
